# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.tail(50)
# Out:
#      City_ID                      City Country  Max Temp Current Description  \
# 198      571                Logansport      US     84.72           clear sky
# 199      575                      Nata      PA     76.87     overcast clouds
# 200      576                   Bogande      BF     89.58     overcast clouds
# 201      585                    Muisne      EC     75.11     overcast clouds
# 202      588                   Kuusamo      FI     77.04           clear sky
# 203      592                   Svetlyy      RU     84.25           clear sky
# 204      593               Valley City      US     77.52           clear sky
# 205      597                      Jurm      AF     77.68           clear sky
# 206      598                    Palasa      IN     82.99     overcast clouds
# 207      601                    Zaltan      LY     84.00           clear sky
# 208      604                      Lasa      IT     83.28       broken clouds
# 209      605        Puerto Del Rosario      ES     80.35           clear sky
# 210      606                   Teguise      ES     80.82           clear sky
# 211      613              Lawrenceburg      US     90.00       broken clouds
# 212      615                     Lucea      JM     87.85          few clouds
# 213      618                Masallatah      LY     81.21           clear sky
# 214      619                      Nara      JP     76.50          light rain
# 215      626              Kudahuvadhoo      MV     81.66     overcast clouds
# 216      627                      Trat      TH     80.87          light rain
# 217      631                Cantagallo      CO     82.98     overcast clouds
# 218      634                   Inirida      CO     82.08    scattered clouds
# 219      635                 Waldoboro      US     89.37       broken clouds
# 220      641                    Basoko      CD     77.22          light rain
# 221      647                  Buchanan      LR     77.83     overcast clouds
# 222      648                     Amapa      BR     89.65    scattered clouds
# 223      649                 Namatanai      PG     78.73          light rain
# 224      651                   Russell      US     88.97     overcast clouds
# 225      653               Mangaratiba      BR     79.66           clear sky
# 226      656                  Tshikapa      CD     86.92    scattered clouds
# 227      658                  Acapulco      MX     87.62       broken clouds
# 228      660             Prudentopolis      BR     75.69          few clouds
# 229      661            Saint-Augustin      CA     76.93    scattered clouds
# 230      662                       Moa      CU     87.76          few clouds
# 231      664                 Les Cayes      HT     89.56     overcast clouds
# 232      666                Susanville      US     81.09           clear sky
# 233      670                Vila Velha      BR     78.75    scattered clouds
# 234      672                      Axim      GH     77.59    scattered clouds
# 235      676                   Selkirk      CA     75.07           clear sky
# 236      678                  Toktogul      KG     78.93           clear sky
# 237      679       Nakhon Si Thammarat      TH     77.67     overcast clouds
# 238      680                  Arrecife      ES     84.18           clear sky
# 239      681                     Ukiah      US     88.43           clear sky
# 240      682               San Ignacio      BZ     86.14          few clouds
# 241      690               Meadow Lake      US     88.21    scattered clouds
# 242      694                  Hamilton      US     87.62    scattered clouds
# 243      698             Puerto Narino      CO     83.66       broken clouds
# 244      700                 Gushikawa      JP     83.43    scattered clouds
# 245      701                     Apodi      BR     87.37     overcast clouds
# 246      703  Sao Gabriel Da Cachoeira      BR     85.80    scattered clouds
# 247      707                  Takoradi      GH     77.38          few clouds
#
#          Lat       Lng                                         Hotel Name
# 198  40.7545  -86.3567  Holiday Inn Express & Suites Logansport, an IH...
# 199   8.3333  -80.5167                                          Rey David
# 200  12.9714   -0.1436                                  Auberge Wendkouni
# 201   0.6000  -80.0333                                       Quinta Samay
# 202  65.9667   29.1833                                     Hotel Kuusanka
# 203  54.6750   20.1347                             Gostinitsa-Kafe, Alena
# 204  46.9233  -98.0032  AmericInn by Wyndham Valley City Conference Ce...
# 205  36.8648   70.8342                                                NaN
# 206  18.7667   84.4167           Balaji tifen & meals veg & non veg hotel
# 207  32.9470   11.8665                                      Fars Alfelale
# 208  46.6166   10.7002                              Pension Feldgärtenhof
# 209  28.5004  -13.8627                        Hotel JM Puerto del Rosario
# 210  29.0605  -13.5640                           B&B La Casona de Nazaret
# 211  38.0373  -84.8966                      Best Western Lawrenceburg Inn
# 212  18.4510  -78.1736               Grand Palladium Jamaica Resort & Spa
# 213  32.6167   14.0000                             Mustafa Taher Sowaidan
# 214  34.6851  135.8049                            Guesthouse Nara Komachi
# 215   2.6708   72.8944                    Niyama Private Islands Maldives
# 216  12.5000  102.5000                                        สวนหนิง-อัศ
# 217   7.3760  -73.9196                               Apartahotel Altamira
# 218   3.8653  -67.9239                    Fuente del Guania Hotel de Lujo
# 219  44.0954  -69.3756                          Le Vatout Bed & Breakfast
# 220   1.2391   23.6160                                      Jackyna Hotel
# 221   5.8808  -10.0467                                Kamaneahn Hotel Inc
# 222   1.0000  -52.0000                                                NaN
# 223  -3.6667  152.4333                              Seagulls Inn Namatani
# 224  32.3502  -85.1999                                               Macs
# 225 -22.9597  -44.0406                         Portobello Resort & Safari
# 226  -6.4167   20.8000                                        Tatem beach
# 227  16.8634  -99.8901                          HS Hotsson Smart Acapulco
# 228 -25.2131  -50.9778                          Mayná Hotel Prudentópolis
# 229  51.2260  -58.6502                                                NaN
# 230  20.6569  -74.9403                                             Carmen
# 231  18.2000  -73.7500                                       Villa Orphee
# 232  40.4163 -120.6530                               Comfort Inn & Suites
# 233 -20.3297  -40.2925                               Hotel Vitória Palace
# 234   4.8699   -2.2405                          Axim Beach Resort And Spa
# 235  50.1436  -96.8845                              Canalta Hotel Selkirk
# 236  41.8708   72.9402                                              KAGAN
# 237   8.2500  100.0000                                   ร้านไอซ์โมสีshop
# 238  28.9630  -13.5477                                     Hotel Lancelot
# 239  39.1502 -123.2078                                  Hampton Inn Ukiah
# 240  17.1561  -89.0714                               Rainforest Haven Inn
# 241  34.8014 -106.5436                                 TumbleWeed RV Park
# 242  39.1834  -84.5333                          Six Acres Bed & Breakfast
# 243  -3.7703  -70.3831                            Eware Refugio Amazonico
# 244  26.3544  127.8686                                 Kirari Guest House
# 245  -5.6642  -37.7989                             Churrascaria e pousada
# 246  -0.1303  -67.0892           Alarne - Área De Lazer Do Alto Rio Negro
# 247   4.8845   -1.7554                         Raybow International Hotel

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start_df = vacation_df.loc(["City"] == "Jamestown")
vacation_end_df = vacation_df.loc(["City"] == "Griffith")
vacation_stop1_df = vacation_df.loc(["City"] == "Morehead")
vacation_stop2_df = vacation_df.loc(["City"] == "Hamilton") 
vacation_stop3_Df = vacation_df.loc(["City"] == "Jamestown")

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start_df["Lat", "Lng"].to_numpy()
end = vacation_end_df["Lat", "Lng"].to_numpy()
stop1 = vacation_stop1_df["Lat", "Lng"].to_numpy()
stop2 = vacation_stop2_df["Lat", "Lng"].to_numpy()
stop3 = vacation_stop3_df["Lat", "Lng"].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 # 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
# ----> 2 start = vacation_start_df["Lat", "Lng"].to_numpy()
#       3 end = vacation_end_df["Lat", "Lng"].to_numpy()
#       4 stop1 = vacation_stop1_df["Lat", "Lng"].to_numpy()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3622, in DataFrame._get_value(self, index, col, takeable)
#    3616 engine = self.index._engine
#    3618 if not isinstance(self.index, MultiIndex):
#    3619     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3620     #  results if our categories are integers that dont match our codes
#    3621     # IntervalIndex: IntervalTree has no get_loc
# -> 3622     row = self.index.get_loc(index)
#    3623     return series._values[row]
#    3625 # For MultiIndex going through engine effectively restricts us to
#    3626 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     387             raise KeyError(key) from err
#     388     self._check_indexing_error(key)
# --> 389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'Lat'

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([],ignore_index=True)
itinerary_df

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd><{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd><{Country}</dd>
<dt>Weather Description</dt><dd{Current Description}</dd>
<dt>Max Temp</dt><dd><{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# 11b. Display the figure
fig
